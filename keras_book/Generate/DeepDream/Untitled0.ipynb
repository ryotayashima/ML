# %%
# !pip install -U imgaug==0.2.5
# Out:
# Requirement already up-to-date: imgaug==0.2.5 in /usr/local/lib/python3.6/dist-packages (0.2.5)
# ...

# %%
# !pip install -U scipy==1.2.0
# Out:
# Requirement already up-to-date: scipy==1.2.0 in /usr/local/lib/python3.6/dist-packages (1.2.0)
# ...

# %%
from scipy.misc import imsave
import scipy

# %%
scipy.misc.imsave()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-84c550aa2d17> in <module>()
# ----> 1 scipy.misc.imsave()
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# TypeError: imsave() missing 2 required positional arguments: 'name' and 'arr'
