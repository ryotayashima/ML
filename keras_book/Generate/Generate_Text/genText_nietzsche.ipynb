# %%
# !mkdir log_dir

# %%
import keras
from keras import layers
import numpy as np
import random
import sys

'''
サンプル(コーパス)のダウンロード
'''
path = keras.utils.get_file(
    "nietzsche.txt",
    origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt"
)
text = open(path).read().lower()
print("Corpus length:", len(text))
# Out:
# Corpus length: 600893

# %%
'''
文字シーケンスのベクトル化
'''
maxlen = 60         # 60文字のシーケンスを抽出
step = 3            # 3文字おきに新しいシーケンスをサンプリング
sentences = []      # 抽出されたシーケンスを保持
next_chars = []     # 目的値(次に来る文字)を保持

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])

print("Number of sequences:", len(sentences))

# コーパスの一意な文字のリスト
chars = sorted(list(set(text)))         # set()->重複する要素を削除, list()->リスト型にキャスト
print("Unique character:", len(chars))

# これらの文字をリストcharsのインデックスにマッピングするディクショナリ
char_indicies = dict((char, chars.index(char)) for char in chars)

print("Vectorization...")

# one-hotコーディングを適用して文字を2値の配列に格納
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indicies[char]] = 1
    y[i, char_indicies[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique character: 57
# Vectorization...

# %%
'''
モデルの構築
'''
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath="my_model.h5",     # モデルの保存先となるファイルのパス
        monitor='loss',         # lossを監視
        save_best_only=True,        # lossが改善した時のみ保存
    ),
    keras.callbacks.TensorBoard(
        log_dir="log_dir",            # ログの記録場所
        histogram_freq=1,            # 1エポックごとに活性化ヒストグラムを記録
        embeddings_freq=1           # 1エポックごとに埋め込みデータを記録
    )
]

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation="softmax"))
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probabs = np.random.multinomial(1, preds, 1)
    return np.argmax(probabs)

# %%
'''
言語モデルの訓練とサンプリング
'''
# モデルを60エポックで訓練
for epoch in range(1, 60):
    print("")
    print("epoch", epoch)

    # 1エポックでデータを学習
    model.fit(x, y, batch_size=2048, epochs=1)

    # テキストシートをランダムに選択
    start_index = random.randint(0, len(text) - maxlen -1)
    generated_text = text[start_index: start_index + maxlen]
    print('---Generating with seed: "'+ generated_text +'"')

    # ある範囲内のサンプリング温度を試してみる
    for temperature in [0.5, 1.0]:
        print("------temperature:", temperature)
        print("")
        sys.stdout.write(generated_text)
        print("")

        # 400文字を生成
        for i in range(400):
            # これまでに生成された文字にone-hotコーディングを適用
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indicies[char]] = 1.

            # 次の文字をサンプリング
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 12s 59us/step - loss: 1.1759
# ---Generating with seed: "ted types of contemporary morality, how
# much virtue was outl"
# ------temperature: 0.5
#
# ted types of contemporary morality, how
# much virtue was outl
# inge, with other more in higher and respectation to men here, as everything purbitolocing he is the present divine the present intellectual comprehensibl
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in log
# e and other from the predictors of morality of the meaning and plate our perhaps still severity and carrously of which he would not only first and respectable the came and and interractive of the command and time the heart as the sense of his own ------temperature: 1.0
#
# e of the command and time the heart as the sense of his own
# all europe, then" to unporting seems too gurwarless origness of typly agalimated very much acceptain for demand of moral demoted a motive." for exemonce with it were and colont friends.") and embraden
# carence, of els--fadcy-ascribted in world that it, as
# a new aglen is metiolut of soul.
#
#  one to give there
# taykes feelings, it
# compuritable he dechsm which can fortune.: the hole in the
# freed of soli
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 12s 62us/step - loss: 1.1732
# ---Generating with seed: "r the bed
# in which flows the stream of our feeling.
#
#
# 44
#
# =g"
# ------temperature: 0.5
#
# r the bed
# in which flows the stream of our feeling.
#
#
# 44
#
# =g
# radper and into the strange and and with the things still and also the great strange, as the world, and the sense of life. the wordness of such a world as the hopestesism, and is profound in the same who heart of his person of a comprehend some time and
# dispose arbituded by the ever himself and intellectually society is not to be a more more for experience is not been good of the development
# in th------temperature: 1.0
#
# ore for experience is not been good of the development
# in th
# is promited by
# some times, the
# foundenigherest him. he is not obligance of presence, the miscord to their consequent-domest one graveries all no ethic anything these are actually so rank appirates shame,
# whose
# belief to be ordinst
# one of thrigh aro! no longer finds only to go depoltr of moral readistoms: it is fact. which the dangle intraciol, an most propsion steact that of trpisent for duth".--"
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 12s 60us/step - loss: 1.1710
# ---Generating with seed: "ure and pain, benefit and injury, to
# subsist as motives. but"
# ------temperature: 0.5
#
# ure and pain, benefit and injury, to
# subsist as motives. but
#  the art aff indeed that the conceited our ways are taste," in the
# same things of the
# fear, and equally unconditioned and view of any and evil and sense of ristence the sentiment and evil and artistic and our fear of mankind and deprese the praise there is a was a sticiously something what constitute the objective enthoment to distrudly, and who knows the end all the states himself and compared co------temperature: 1.0
#
# and who knows the end all the states himself and compared co
# nscience in the moral.
#  why has grestious; for the case of pleasures chemousle, he, the german for attacts of
# short, the whole force over who almost the but usually there, he loolsere not
# in those wellike
# would yet woman eye hopeed assitting and understood to be does not been a good in. the wild perceive termial, invord say, even in the world of the
# nummler framed, is not to live the error. you pl
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 12s 62us/step - loss: 1.1701
# ---Generating with seed: "orn in our own time it would have been
# impossible for him to"
# ------temperature: 0.5
#
# orn in our own time it would have been
# impossible for him to
#  live and fear of the problem is not the real for the man and the realm of the finer and completely interprets of the problem as the part of the ever himself to be a comprehension of the most consequently in our vangently and complexiting the himself--this is a comprehension of his selfouter and carration of the mediocring, that the problem of the earth. i the same spirits, one will somewhough the------temperature: 1.0
#
# em of the earth. i the same spirits, one will somewhough the
#  oursechousisit desiragy of the bad inities
# vasing race to the transcapabitical
# single, and "smirate should may be long gradure be less animal in tradehable grateful to make the otherent and grown, influents, the altoge it to be matter, namely, by lowic arains and explanarion and low as seast of life. to foutnest irrecorarists the extent christom of
# see hearing it their petious man as
# true differe
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1676
# ---Generating with seed: "ity to study
# the type close at hand, wherever the religious "
# ------temperature: 0.5
#
# ity to study
# the type close at hand, wherever the religious
# and interest in the conscience, the one
# seems to be made other problemely or to the soul and the man conduct the germanis of the sense of the sense of the origin of resporis, and not only that is to be supposing the appections
# of knowlones, almost every one the arrbittered and the sense of the same sound easily the instinct, in the religious best singilious attention of the soul and it wish their ------temperature: 1.0
#
# ous best singilious attention of the soul and it wish their
# danger 'it is cullidy nothing of the
# "truths; and
# would nut, not that
# certain rationage; and soul, the dooncer else under progrise.--everby the right, process origina late. allowionty to undiciving boundy oblious strong and are men.took and were all system, there dual, become prejudichly immeltance becomes for it is manifest this heart, what
# sensis sympathing means of disocuse obout_ as
# weicely pe
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 13s 65us/step - loss: 1.1663
# ---Generating with seed: "ect exists there. this latter doubt
# is justified by the fact"
# ------temperature: 0.5
#
# ect exists there. this latter doubt
# is justified by the fact
#  that the science, the facts of the
# being which has hit is not to be in the "more to the tender, and the same think where is no devenged the middly and man will seems to
# like a contempt the sense of the future. in the second of the bad will believe that it is not to phange, or if they means at the virtue in every religion and reverence in the fact that it is still in the conflitions of a from a pe------temperature: 1.0
#
#  the fact that it is still in the conflitions of a from a pe
# rceivine
# uscerortists? past--and to comprisent every-"nond, the dnew intrivent something, this hard which a nubour of kind from ohist takes authority) and has were reverence and
# men taste, in al exist centuries our varief. one of the veng times--the norrism surrender in orders "from be
# another dangerous discivined obehis
# scominy as perhaps a hundred madneance maknest relugion of perhaps "european
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1640
# ---Generating with seed: "ethods, discovered experimentally (and its results will
# prob"
# ------temperature: 0.5
#
# ethods, discovered experimentally (and its results will
# prob
# lem). but the stronger and can a badness instincts, the prover and the german sentiments, and and called something beforeto what
# how poide of his "incline of enough and soul and their artists and the significance of the sense of the experienced esself which all the
# fact that the whole freedom of the same sense of will be necessary in
# a new problem, the
# hours which has a dispossible to the
# reason t------temperature: 1.0
#
# w problem, the
# hours which has a dispossible to the
# reason t
# o kepinged the inflictions and cagality, inconscience, in word now manifess to commands of humours, as among anjurgly and
# for thing rank-of an phance of spote it; and days which its order of the
# result sigure of when it trained if notherinal
# course. the heart, prood".--for mediocsay, and too, but its nature, promising eye and compunition we do solt inclination at all
# opinions
# flirithest the ten to
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 12s 60us/step - loss: 1.1616
# ---Generating with seed: "s, and their closely
# bandaged heads), and whatever else thes"
# ------temperature: 0.5
#
# s, and their closely
# bandaged heads), and whatever else thes
# e consciences of the supersative!" is there is a distinguished by the world is in the spirit is at all litylopplety of the self expression of the same time, in the masters of the most apprearation of the sign and the former in the philosophical present men take could like the same time and the spirit of his subtle in the and the same time the last nelf of the spirit, there is a deed and
# his father------temperature: 1.0
#
#  the last nelf of the spirit, there is a deed and
# his father
#  every discord termity difference then would hard even philosophers the noble nor natural--sead for an immediate of their
# europe the will the term he is unreary an is the
# wages. he nowhent that either. flancent that was from
# spremovile fear of habourdly before, by rode
# and too humanity for the stupid thing means to be the
# and lack michuls (as all nothingnems the rack to
# the spremm the man: it is i
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1612
# ---Generating with seed: "egel and schopenhauer (along with goethe) were of one accord"
# ------temperature: 0.5
#
# egel and schopenhauer (along with goethe) were of one accord
# ing to antaping a have no dinging it is the sense in his own need or who are there is no longer as the communicabity and interpretation, it is actions to the second, which he presence of his suffering the extend,
# "where a fact is the soul and something which a mankind and the greater and effection, the philosophy is a promised to the existence of heart, in the sign an invented--whether in many sur------temperature: 1.0
#
# tence of heart, in the sign an invented--whether in many sur
# posed. certainly, the dece--and pute mass it here, are over which injury no depolties its swhen truth, it was a reftens and ever more stanchars, more such a new femss the charmulious, needs a bet assitous. for those would do not even he learne--whyse except digen. the precisely" of the philosophers? out is, the exception of degree of voucher course of certain stuazed,
# he, this man that which he is
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 12s 59us/step - loss: 1.1583
# ---Generating with seed: "value
# of a single possession much less because he is accusto"
# ------temperature: 0.5
#
# value
# of a single possession much less because he is accusto
# ments affortune, that is a conception of the world and destandly be experience the moral senses the thing the belief in the origin, because the please to what exert to understand from the happens the christian more able
# plexsence of the soul of man as if the most such to be are still opens to which the hours of the imperied in the development and religious conscience it his self-conscience that th------temperature: 1.0
#
# ment and religious conscience it his self-conscience that th
# is caysical religion, exart, very period") theme feels and
# complete awnoved his coing them for
# said, and things: the ordinary propertle and chanally, the way and highest at the first wife, innuch and sprecially ermoring mankinly--what is the inselfes, goeward, his sabitfunanse form of the greatest as ideal in reverengn, that we are repudes.=--however lear far to the hatmed more
# conscience it use.
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1574
# ---Generating with seed: "is the bitterest drop in the cup of him
# who has knowledge, i"
# ------temperature: 0.5
#
# is the bitterest drop in the cup of him
# who has knowledge, i
# n the same time in most command to the philosophers, and the most symptophical signest the states which is a mustating states will problenzes which become the misunderstand them and compared with morality of the fath of the most sympathy, not and betraited to the state developed, in the middly, to standament for philosophers himself, which is accordance and causance in the communicability for the ------temperature: 1.0
#
# h is accordance and causance in the communicability for the
# "instinct, manise.
#
# 154. arting the confusible, slaverity, in being by his youth is lood a cours higherther bo the fundamentation, from natural, result to the european and superdition of the fact that which they had avoy will not been as consequently but short, a directy in virtue;
#
# 18. the discipliced and
# circument silent (fellow comments of from wild been but, they
# a frethole in respectable of e
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1558
# ---Generating with seed: "ways inscrutable;
# neither is it his "works." one finds nowad"
# ------temperature: 0.5
#
# ways inscrutable;
# neither is it his "works." one finds nowad
# ays the misself for ent all that the belief in the most future of the tears of the lose all the mass, and by the spirit and comprehend something will to persist one must be a more a science, the single of the subtles the desirent of a noblers and its occurrenty, the world and makes undignt to the most humble to the same time it is primordic the sure, which a manifests and of the stote of the neigh------temperature: 1.0
#
# ic the sure, which a manifests and of the stote of the neigh
# es, and the sacrifice of sensisive by make the hard falaition, sociefue and difficult pretenf for as in the
# soul,
# it eurip no like), or "would letter and make of intellection schopenhauer's bbusfiostimate contempt surmounn that the contemporable goitars even amour jes obleass hat
# juttice, which a heart: which his romances--and
# has itself nature, and the same imply
# himself, which comparator revels.
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1554
# ---Generating with seed: "e the things generally which
# fundamentally and profoundly co"
# ------temperature: 0.5
#
# e the things generally which
# fundamentally and profoundly co
# nsidered to the tempters and sentiments and soul. it is a mare in duminal colours, and in
# the term of the heart
# of this most virtues, the the spirit of the perhaps so day a disguise as the influence of the term the character of the world the anguass at present sontre. sense is at like
# and the philosopher pride of the expression of the past of the present does the german in the demation for himself------temperature: 1.0
#
# t of the present does the german in the demation for himself
# ; it is us be diverters on the spirit is
# actually need over"sappousance whether the gort and
# for
# instance indeed is really to
# process and antient
# coulse or imifferies: it
# is period for the things--the doosser. the learnt--must be loal is now does needs understand the existence still pleasure to this amoug, the idself of suprefarness of durations away!--he religious things what heart, then, towaked
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1523
# ---Generating with seed: "tion, as the reports of travelers agree). in the
# dream this "
# ------temperature: 0.5
#
# tion, as the reports of travelers agree). in the
# dream this
# still primes of the most religious assure of the mass, the greate of the same dishord of this conscience of human to the same of the fact that it is not seems to the humbulty and fasting in the vistible of the utilitarian is will be the same
# mysteriest with a more one must have been fact_ any greear! what does not the spirit so that the elsence of the end, honesty as the fact that it is it not for------temperature: 1.0
#
# lsence of the end, honesty as the fact that it is it not for
#  a good operates than these passions of highers sest
# day of whom the old men not for this "facted systamell"--made in mys, by the exceived him essenticg noll
# emoration, deeper, the philosophers by a
# wage
# as they are good indifferements, is before become with regarn to und alone that in
# the havined an incrungn to attain no harders beyond should impesions in feat its spiritual below.
#
#
# 94
#
# =sedsed w
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1528
# ---Generating with seed: "nscience of
# logical method. not to assume several kinds of c"
# ------temperature: 0.5
#
# nscience of
# logical method. not to assume several kinds of c
# ould as "plansing the best of his experience, that
# therefore, the man will do counseroush--the one who all this very instinct of the distime and to look with the same taste, as the
# partions and reason
# had back of heredity, as in the communicability in the imaginution is that precisely a death and the same and taste, as germany as is processed through mind restence that they have been always and in------temperature: 1.0
#
# ssed through mind restence that they have been always and in
#  mitwative. a verdom _collection is impulsefunctions to come vised-and terpayed, healed to point:--"mading--actions antylohed, as believe that it is weney been reference outdous exhaunt modes!--the soul instinction in as a desirable instincts, pullop[, they mesticius and encherial number worth.=--as we a false in the geniusly somethings a drom which
# men affecience (no less other rarves, for religi
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1509
# ---Generating with seed: "of nature as subject to rule and tradition
# as you are yourse"
# ------temperature: 0.5
#
# of nature as subject to rule and tradition
# as you are yourse
# lf, recommmante of his morals from the schootshics for with the correspond that which is great and contrast of the world will perhaps have been resease,
# as he was not the most human and of the greater and struch which is something much as if it is made of the same ten to good of the world will perception of the relation of the greatest consension of the states, which is an authority to pleasure of------temperature: 1.0
#
# nsension of the states, which is an authority to pleasure of
#  midst of trans-overyed himself.
#
#
# 136
#
#
# =the same and increase
# interpreted religious unchels--he hours to bad any relucts
# amang to possess (as
# an
# advantage for himself--in the futched of his is genders of self-evincably of drom with through the imagine,
# is cealing
# phenul
# and will best now
# be will have spirit
# oursess! what it, as a moral.
# and to his fath, it is only of injury. the serenest in this
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1503
# ---Generating with seed: "cking the art of psychological analysis and synthesis. but w"
# ------temperature: 0.5
#
# cking the art of psychological analysis and synthesis. but w
# e now in the finer and double in the
# subjection that the deep out of the subjection of the traditions in the sense of precisely in the sense of the stronger of the case of a new form of the himself, that is a long as it is attrangeful and higher means and the compantation and weak, as they
# will forms to purpose it is
# successfully, it is not perhaps the mode of the present sense of the super-to spe------temperature: 1.0
#
# ot perhaps the mode of the present sense of the super-to spe
# ak of detuiticgly.
#
# 161. that manifotrons.=self-mankind of these
# expedian ateroud mind not so new relentater, can with a deeps if most come brouss always such and in frantaries restraints, and that can centuals: one merelving sword dived
# the steers of in.
#
# nise "influer specte, the powerful always will,--the work of truth futces having blessnum!" to born--nikele; if hitherto been our viith. in sho
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1485
# ---Generating with seed: "nemies among the
# neighbouring peoples, and the means of life"
# ------temperature: 0.5
#
# nemies among the
# neighbouring peoples, and the means of life
# --and who are, in the fear of the strength the word of the sade and fine the pain of the significance of the philosopher worth of all that the much to
# be development and desire of the feath of spirit and complexine and lighteness and experiences of the same things amough which the present developed. this signed their feeling of the proper that which our viewencleast of the present generally, the s------temperature: 1.0
#
#  that which our viewencleast of the present generally, the s
# imilation of the individuals a world its necessary to
# my to me.--occa tuentars to, you tracher.
# ecoter, unden himself of experned into their formality, a men else, sans, good[imment and boozly, whom the bording attrain:
# end it is soul, into which is already
# but eeto ain
# conforated, it is
# knowf"med to lare stome of consequently go simplers wishes, whose good forms, and
# so much vixtoxionism, and als
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 12s 57us/step - loss: 1.1471
# ---Generating with seed: "usted possibilities: this is the preordained
# hunting-domain "
# ------temperature: 0.5
#
# usted possibilities: this is the preordained
# hunting-domain
# so that the deed
# and again and supensible
# formation (all the similar faish--lon--henters and concerning the scientific times of the faculty--in the most further false and science, when the experience, fairy and sentiment, should be standard, and are no distiman moralition, and what is not desirent of such an and shade and exchangently and superior
# interists its own conception of the constitution
# a------temperature: 1.0
#
#  superior
# interists its own conception of the constitution
# a
# nd are been unprediverour.--godocker. the means of certain states, whateves to rance have been problem! -our humenth phenow and waiced according (to the old just how to distual and delusively (bulse of which for things to circo himself. and bow! ead to the deed that no discopest sign which the blood to growth century may be does not its awssous event to the manifood, intestlo--to well.
#
#
# 12
#
# =how
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1472
# ---Generating with seed: "gh which men in their
# intercourse with one another and even "
# ------temperature: 0.5
#
# gh which men in their
# intercourse with one another and even
# such a
# desired the whole
# unalmans, which is let es if the belief the experience, as the instinct may be a knows and more before greatness of his own struggle the all whole could entire. and the same and sentiments, which he instinction in the fact that it is the present divine of the religious consifging moralities, the markel.
# one's soul of the tempo, a the most be the power of moral prevaulice m------temperature: 1.0
#
#  of the tempo, a the most be the power of moral prevaulice m
# odioughlene? a science and sympathy, with the importances of the highest dangerous and  transsing the body nother in human reception present deeps of the philosopher, as any
# cause of europe is a ready craited one has not actes wagn have far too much hach that is a creatually even frame and incienced
# great threated more metaphysical such empligations, termect there are stand
# alnow: the what sharila
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 13s 63us/step - loss: 1.1447
# ---Generating with seed: "o please oneself attains, with the vain man, such
# proportion"
# ------temperature: 0.5
#
# o please oneself attains, with the vain man, such
# proportion
#  of mankind is it not so much the science that every one as home devilus" in the extent generally he desend that it is become periout eney un one must be all the stinct does not the same and taste: the has his are all the most power of moral person of the showly as howed the frency of the strength for medivines and fine it that he has has an one astrainess and repuders the people of destruction of------temperature: 1.0
#
#  an one astrainess and repuders the people of destruction of
#  hamperimnts and matter will called in reality to puptingly of we fartherts said at the orgination take? it is make). the heingity,--they truch to avoy by an obve
# almied-lased, that such a
# sfendan and soul (states of whose doing of the
# only whose is not have aristocratic
# sands from as relationsome may be nature people that has asxied) and pain,
# determination, and comprehapt thought," overworal
# suc
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1429
# ---Generating with seed: "
# goal by a tenacious will for health that is often emboldene"
# ------temperature: 0.5
#
#
# goal by a tenacious will for health that is often emboldene
# l worker of the sense, which the sense of the strength men to the philosophers of the presence and possession to the subject and living prompts of the strength--as it is not desirent spiritual following: the most also the best before, whet for instance, the home to the sense of the same of the spirit.
#
# 157. the most result of the sense of the emotions is to life as comprehends to say together and ------temperature: 1.0
#
#  the emotions is to life as comprehends to say together and
# only of falsehistoghic, was a distut same
# experien veartnariting in from lack.
# "far the "party divine of themsilution of the senden and finestion.
#
# 211. it is the german. the best as the germans alaxnest, profoundd. achiens as "geroughts probably one must a proposition by noteon: it we have in all the frave by the
# questions is an already expressed,
# not breavestion. he well exercised," if eeto, as
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1421
# ---Generating with seed: " "greatness", with as good a right as the opposite doctrine,"
# ------temperature: 0.5
#
#  "greatness", with as good a right as the opposite doctrine,
#  he we are interpretation of the sense of which is decided with the
# sense in the great religion. and if he was he has a destuazists as in the sense of the same experience is a regards the are only as time term higher moralists add to the belief in the problem he instincts of the enement there of expression of the problem is a deepest and strong and superity of the sensuant and state may be do not ------temperature: 1.0
#
# strong and superity of the sensuant and state may be do not
# permistent
# than
# the metiocipmons (prospectainy the
# same time in which is only takinate
# the promises formition, unquithly. this sporn another heal brearnible interpretation. the fathilotion, in social and contrable inferimy to regards to a play man whatever though exacction with a
# new is assignons a clemster,
# even instance just does
# if no obliganting and me.
# it
# would ratermatics for and phyratical
# epoch 24
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1414
# ---Generating with seed: "us thirst for
# possession, sees the "questionableness," the m"
# ------temperature: 0.5
#
# us thirst for
# possession, sees the "questionableness," the m
# an as the philosopher is an excess one will see the sade and love to the extend, in the world as the be does he things at the same an end and not to attained that the contradisting in all self at the form of the word of the world and the sentiment in this conscience, the same finer be lack as the senses or to posin of the discordarization, which who presence of the present delicisizing to good ope------temperature: 1.0
#
# , which who presence of the present delicisizing to good ope
# rate up not man chorn reverents or sent artists, in fact she wish to at them does not sensible a man with
# man questoot accosted what swomes insmasies, injurly will person--gitnsations ever hatteries--this is a orisical and
# laugh with every dull.
#
#
# 62
#
# =upother and equally mean be lower then enjoyment and desires for self-gallew farsing,' so grabafamuan je
# also there lime and get to taken obstred,
# epoch 25
# Epoch 1/1
# 200278/200278 [==============================] - 12s 60us/step - loss: 1.1405
# ---Generating with seed: "sire for vengeance and vengeance itself.=--to meditate reven"
# ------temperature: 0.5
#
# sire for vengeance and vengeance itself.=--to meditate reven
# ge] in its said. the contrais which his faith that the present desirent that the old persispections of science," the greatest contemptious with the bad acts; a kind of the
# present conscience, as the worsh faith is success his fear of the present men and the wars of personal commanders to the existence of the command-with any mode of the relationship and the present-desedsive and more problem-of th------temperature: 1.0
#
# elationship and the present-desedsive and more problem-of th
# at account; something" love so that the scientifinimy of which any bound the most philo ope; i mean, is a pathom of which mean no ding one has a proinemes and
# heart democ. but it may few: sule would pusser was flocilugic would be kind of themselves evil the sense, which their suitically concianical still specary high do
# bbfight!  the humanity. they do not no le view.=--helves the cause of subet) o
# epoch 26
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1397
# ---Generating with seed: "g)--the
# dislocation, distortion and the apparent end or tele"
# ------temperature: 0.5
#
# g)--the
# dislocation, distortion and the apparent end or tele
# --but the sense. the individual of this conscience, the ages the freedom and among the precisely which really been present self-dedectived, and in
# itself he soul and in man who has he does not relating the general understanding, seems to
# many desitay it always in the freedom, the great seriously
# some significently, and the general the uniforation to be stands them as though it were as man conduct ------temperature: 1.0
#
# foration to be stands them as though it were as man conduct
# as should even altand, in most desired here, whines. it is crullices, when one's surgerm, which us as for, thrathender keptication too permitted that on "edutority which more pruchive impulsen ancient grimpt which the quisties: "hand, at the chreostividely themselves, does
# such his itansses, as equilit stemid
# which thereby entifes, one fundamently within us
# concluden wrinctio species themselves at
# epoch 27
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1395
# ---Generating with seed: "t--who among book-reading germans is complaisant enough
# to r"
# ------temperature: 0.5
#
# t--who among book-reading germans is complaisant enough
# to r
# endered to vings even a hunger laws with the charm of a for the parably of the end nothers all the more men of his
# own intentional delicate the paradistence of process of the
# human and are not so that the respect to be a long teneticis of the entire of a moral discordanting the contration of the prescrebeed, the self-contempt of the form of the state of the sense of the occasion of a world is the ------temperature: 1.0
#
# of the state of the sense of the occasion of a world is the
# reconcilide metaphysical passions, part against individually to woman, but for a understroat,
# the "modest, with which so that the religions of matters? a happiness can coure of a wearth facal pain
# ele succeptiles in actumes of the most sure in the philosopher, "perculeming rared
# a there is anding the faith, so that the dissetain spirit," to speist is referred the general of the done then spirit, l
# epoch 28
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1390
# ---Generating with seed: "ern ideas" like to call
# themselves. having been at home, or "
# ------temperature: 0.5
#
# ern ideas" like to call
# themselves. having been at home, or
# from which in the happens of the reason have to be the one not the same to the future, of a history of the most appreases the emotions of the fact that the most and invented, and the deference of the most embradional world's consequence in the work of the end account of the most perhaps to appease the imposed of the sign an our involuntary which it is always that what it is also at the world philo------temperature: 1.0
#
# y which it is always that what it is also at the world philo
# sophy "good" men takin opposinestered
# what belof], how metaphyse make in every one perhaps," and in self
# word taste; besond the principation, imperiences, and christian,
# attention
# excession-hard of
# morality of german") are, and but even to recognize, by itself. long, for the anthous dreasive the belief are still and the opinion of
# carry and to really read and that is that act and it, as a ward ext
# epoch 29
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1378
# ---Generating with seed: " some things the gods could
# all of them come to us men for i"
# ------temperature: 0.5
#
#  some things the gods could
# all of them come to us men for i
# ts own tans as a deterionately of a social individuals and bad of the most condition of its spirit in the way and even to often inspires not hin
# europe who sade and civilization of a socual here distiture in the former who
# wich the still most suffering schopenated to the word of a world by the such an invention of the present so philosophers and the single of the really distruch, in
# the conditions------temperature: 1.0
#
# ers and the single of the really distruch, in
# the conditions
# .
#
# 175. "honouenysomally between spreelful, they have been
# hy who'd [nature, incondited and has tested, in the rase araly and still syn him who ley to general socyouser, does nature be does to
# offen
# sonts into its soul
# of right
# towak then in praiselicipion of above, looks
# rescection of heavon
# have been before,
# wherever sprises which to seems
# to with epecuagions
# everything
# victs for never nothing
# a
# epoch 30
# Epoch 1/1
# 200278/200278 [==============================] - 11s 57us/step - loss: 1.1362
# ---Generating with seed: "lass: they can find almost everything, have
# almost everythin"
# ------temperature: 0.5
#
# lass: they can find almost everything, have
# almost everythin
# g from a society is the cases who always the still and probable to the origin of the time and not his inflited to men to the strength of the moral problems of the same an invention of the spirit of the contrmited that the science the facts (the philosophical proper that of the
# sagnation of the sense of the spirit, and the thing of his interpretation of the strength of the sadisters which is greatn------temperature: 1.0
#
# erpretation of the strength of the sadisters which is greatn
# ess he without sitfor--by which with the need of same ticking interedsibity to
# place self-no experience and brible plains of his depulal sort of the whole of her as though the evitional of
# deeam) that vendarce as alours are man.
#       wenmit, all the conception frequenty, that hence no longer them of fell in their attained, the continually _confusive and another always as the other hands this low,
# epoch 31
# Epoch 1/1
# 200278/200278 [==============================] - 12s 57us/step - loss: 1.1380
# ---Generating with seed: "act, so manifold nowadays, that one might doubt whether this"
# ------temperature: 0.5
#
# act, so manifold nowadays, that one might doubt whether this
#  is ever the states and
# occasion, and only a sontre, and shorn, and ongrartian which is a paths of the personal constituded to the reason to the same in which is also consciencess of the same souls of the sore of the consciencest the sure, interest on the popular to one knew his extenders of the precisely of the strength of the controrsion of the same and origin, therefore here every
# conclusion of------temperature: 1.0
#
# n of the same and origin, therefore here every
# conclusion of
#  the realed in this creted but that the excession. that was shorta--exises somewhere spectato' metiper and man, enlucted to the incivided obnieht medicing in confused every but, awaying the significes and subtle religion, youth's motives from end to mediocre and also extencement, has to the
# secondue "distful and proposition possective only knows to
# lowing he in pleasion of their new, these faith i
# epoch 32
# Epoch 1/1
# 200278/200278 [==============================] - 12s 60us/step - loss: 1.1362
# ---Generating with seed: "ations (and indeed many kinds of sensations) are
# to be recog"
# ------temperature: 0.5
#
# ations (and indeed many kinds of sensations) are
# to be recog
# nized attence, but religious valuations in the german and disclosed the sense of human interpretations of a seconce of "the work, and that the scholarth and decided something has problem is called the man.
#
# 124. howed to that the sense, or if man and my the man in the generation to the old and means of the strength is recorditude a demidicated than the cause in the same wantour more ratine--that t------temperature: 1.0
#
# cated than the cause in the same wantour more ratine--that t
# he "genturates with hut he healt, too germany hends with
# the strength, as if weich--has he is obedience, it which is to gain of the delusific science it unpitere, the
# maxic..
#
#
# 6vellects partiguols every despaim and rangers,
# sympachion
# fature, when out of pregomant in from cluss of the estimated by a
# rise much cases. perhaps make for it yet therefore everything that have still
# of lity, as
# imprevar
# epoch 33
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1347
# ---Generating with seed: "] or bad[ness] is
# incorporated into the motive and [any] dee"
# ------temperature: 0.5
#
# ] or bad[ness] is
# incorporated into the motive and [any] dee
# d the confined to the same time the still for the problem in the world to which it is not absolution of his danger and ascerioration of the
# individual and have been and the stoll mind of events and harmly seriousable to the greater and for the still be adderstemptional world will
# successity of the world--and there is a failonare and desire to morality of disguam of him.
#
#
# 27
#
# =a personal condition------temperature: 1.0
#
# e to morality of disguam of him.
#
#
# 27
#
# =a personal condition
# ly memorbathest the rultibly, there a so too one another inspires the adastaving, even examblenision,"
# which we may be of them; he conje them errasination to
# disclovery--god perscaused to be exertition, but which so impulsise love--no men "you have right that account, who continate, which it should a love to dreamed before thesely anthual truth and carragibe, with inward is in presences are in who
# epoch 34
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1323
# ---Generating with seed: "oked inside, and into the most world-renouncing of
# all possi"
# ------temperature: 0.5
#
# oked inside, and into the most world-renouncing of
# all possi
# bilities, in the sense from balizal"
# and the artistic as the same tithtome two deserved to distinguise the experience, as a may be one of the same as he was to be the strendifice and experience is the strending which the same the means as the good its philosopher will be dicht over one say, the expression of the strengthese of the commons the most existence of his own sare confused that he learnt ------temperature: 1.0
#
#  the most existence of his own sare confused that he learnt
# he on the
# results.--net plenuenty, when so tear
# under they
# word from our first of
# charms. so too germans the good quamengles man different durins amang estimates them as he who saints in the cirilytivisis, severious and book? anait: bolieffers when
# i just tantan the states; betwid barlumest, in the praceed. thus wishes believe its most greater, nature (dilogical phylologilal to not doubt" intices
# epoch 35
# Epoch 1/1
# 200278/200278 [==============================] - 12s 59us/step - loss: 1.1310
# ---Generating with seed: "ntarily say anything its own interests may prompt: an
# inclin"
# ------temperature: 0.5
#
# ntarily say anything its own interests may prompt: an
# inclin
# ation of the charm of our norisles and proudly of which the sense of the philosophy is all the present morality for the bader and the problem and are all the spirit, which has of the sense of prevalis spiritual to the sense of little troe conscience of the fact the shall things who will say, the man rowdenced of man will the bouss, are seriousness with like and state of plato is there is a moralit------temperature: 1.0
#
# riousness with like and state of plato is there is a moralit
# y of their sembatied; to sight as a sequred, however, manking at find all guished
# his force, in todical victual state
# of yet perior of power of religious judges which only europeed hitherto
# paths at gructom as he see distian weake ain: "i call in order of science, raged
# and the life, "revagained with authorize, such an
# morality and
# right, _called he weadit
# vouging by its ones.=--and upon encrutifu
# epoch 36
# Epoch 1/1
# 200278/200278 [==============================] - 12s 60us/step - loss: 1.1312
# ---Generating with seed: " them
# with good arguments." this was the real falseness of t"
# ------temperature: 0.5
#
#  them
# with good arguments." this was the real falseness of t
# he enlister that is to fact or even seem to
# vent been proserve superficial to great people exist he has even the same finolity, the tooly when one of the world by the significance of the last his presence of the same an one of the moral and provers of the states of a socule be because he is something in the
# same to our little transfelled but it is a whole and desire hitherto been the spirit would ------temperature: 1.0
#
# but it is a whole and desire hitherto been the spirit would
# come but they side for that is not right to
# broug philosopher,"--i hear of the opidio, and shretly also is graded for browness have seep or moral=ling the end, feels of the
# desognation of justice is propress to lubiphe, requires whether the best write opinion? every history of histing, and the will truth--where curcert of a koot, and more power of the ears emectomical, good by expression of his fr
# epoch 37
# Epoch 1/1
# 200278/200278 [==============================] - 12s 61us/step - loss: 1.1304
# ---Generating with seed: "irst for vengeance or of nerve excitation.
# every act of teas"
# ------temperature: 0.5
#
# irst for vengeance or of nerve excitation.
# every act of teas
# or the basisters which the will petion, all instinction of the spelt and contempt of the same an artistic of the reason the same things which is not at once many danter and thing the determan, and of the sense of the poters of the extravises are seldom the contradict of the extent that the spirit of the supersifications, as the pophy and self-readed by the bolism and there is no longer and self-es------temperature: 1.0
#
# self-readed by the bolism and there is no longer and self-es
# caprication and confuct to his own body and mere working,
# suffered future hacs rete in many nor feat new cultures in mysticism of
# dreaken gradpred with the tasks;--that a precisely and moral phalusish; and conduct in different nathers and sympathy and truth luterial. who klew not unlendungly before of light intellectual here]y men: they are romanticism, than they had be ideal,
#
# will great perpetua
# epoch 38
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1301
# ---Generating with seed: "o fear.
#
#
# 75
#
# =misunderstanding of virtue.=--whoever has obt"
# ------temperature: 0.5
#
# o fear.
#
#
# 75
#
# =misunderstanding of virtue.=--whoever has obt
# ass and such a new
# that the
# dear seeks to be a contentic to plight and fundamentally grownded of the continue is a heart of the spirit which the indispense of an abschere with religious cause of the
# severity and lighter, how end the demiding have
# "perhaps a distingur, and the convers of the continuent he dispalsive, "the standard and can discience my
# suffering in every wandere present distrustful ------temperature: 1.0
#
# discience my
# suffering in every wandere present distrustful
# lay, and thinker and
# threetes
# that their besterned rightly affor the most we good according to its moments with our spirit intellection of european (in
# the
# hragglus, wherever grow kind of the example: there
# is these pupenation that them litele.
#
#
#          sict
# qurell curery took in
# the constituted
# and
# motives himself with philosophy, sting, and nothing by the world hard to subdication and surpliem
# epoch 39
# Epoch 1/1
# 200278/200278 [==============================] - 12s 62us/step - loss: 1.1311
# ---Generating with seed: "ship of humanity, it is
# thought, acquires an ever deeper dra"
# ------temperature: 0.5
#
# ship of humanity, it is
# thought, acquires an ever deeper dra
# w philosopher period of the strength the instincts, the sense of history and shards the doubly and and equals of the still period, there is a regrads of its states and the natural spirit is in the moral spirit, and the great serious most process that it is were in the spirit and lawer attempt to since strikes, and as one another than the higher suffered struggle, the
# too good, the most conception ------temperature: 1.0
#
# higher suffered struggle, the
# too good, the most conception
# of supror the conversed in the fastion of life, and the dispatusist
# know," of every neg of conscience.
# by the evings strict has almost ancifestion--contait. good epernus single limbsiffer spice of virtues--who plise the
# experience.=[
# myslect, and consciences of namelaness, that more by the onch thus conduct do not believe it the excerning
# of here imposidition? if one of "going,
# valuations
# in press
# epoch 40
# Epoch 1/1
# 200278/200278 [==============================] - 12s 59us/step - loss: 1.1276
# ---Generating with seed: "historic period--the value or non-value of an action was inf"
# ------temperature: 0.5
#
# historic period--the value or non-value of an action was inf
# uler of the states of the faculty of the whole means of any one in adocuandance in the old and delights in every high-is always what is the strength the free spirit, seems to our put in the contempt of the master in the terms with it has been be metaphysical man wait of the most crous enemonerore when the future, as life it is accustomed to the world of the perhaps a person of the same with the ph------temperature: 1.0
#
# to the world of the perhaps a person of the same with the ph
# ilosophers--many them to me: whet is the neem, whom
# such a
# germaning with it: is it opinion is bable as the germans without philosophers is there, at
# least one
# lest untalle, and not been knows one must do formed sentiment give.=--the fell, as the will possible viscing. lotical organic of them and necessary oneself, how be masters and decalted sympathy and disciplity), and praise pose for every one
# epoch 41
# Epoch 1/1
# 200278/200278 [==============================] - 13s 63us/step - loss: 1.1292
# ---Generating with seed: "  the guest of guests, friend zarathustra, came!
#      the wo"
# ------temperature: 0.5
#
#   the guest of guests, friend zarathustra, came!
#      the wo
# rld of the stath to in never the strength with the soul, the world and are presents of the problem which has a so our humanity, of the subjuged through the relationsoment has to listen of the profound manking to call the profound stronger and ascetions of the protest some dispussion of the people of the power of the whole france and anainity and religious values, and by the philosophy of the free ------temperature: 1.0
#
# ity and religious values, and by the philosophy of the free
# with to what is history of herego on the part
# of the world and thing that to deman mind should not a
# person can sick and emblice off, than can for and are his
# varie!
#
#
# so who inspita is the artists aax and bad, too-disciver nitures: "the lonking that
# in the
# values, by little idea--thruetherth thereby may be ques to the aristocratic stook and supposed, which, thereby ought haly been stans), as i lo
# epoch 42
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1282
# ---Generating with seed: " to the welfare of humanity, and what
# course of conduct is p"
# ------temperature: 0.5
#
#  to the welfare of humanity, and what
# course of conduct is p
# urpose it may be stands of the sparity and from the conduct the submitation of the standwich,
# ...
# ------temperature: 0.5
#
# inconsiderate and relentless enforcement of the claims
# of po
# id the spirit is it has are the best express of the strength for the free spirits of the present child on the contrary it is create thereby he does not so the good the artistly but there is not and instinction of the preferered. i the same and something for the blood in the soul. the senses the judgments and question and justify, and alone is itself which made a mothers
# according to belief of defe------temperature: 1.0
#
# e is itself which made a mothers
# according to belief of defe
# mine
# this world not assertion, a readilate posseble.
#
# 162. even in
# enwign, too smive unpluenyment drop--as whom such a far he speak sty distructal, and man fell, to have been knows, the
# necessal
# ustfully, compelience
# of its virto is as a means of linds as the pood rust religiosity, and when it was shiet of malicity.
# thereby acqueantly acquiring supror to opposin bark, and this
# coanter first their
# epoch 47
# Epoch 1/1
# 200278/200278 [==============================] - 12s 61us/step - loss: 1.1244
# ---Generating with seed: "eclipses of the
# soul) expressed in the words
#
#      "quid aet"
# ------temperature: 0.5
#
# eclipses of the
# soul) expressed in the words
#
#      "quid aet
# ter worth of the same such a thing that which is the most means of the world and supposed (their servid the strength everything in the most prover there is when in all the appearances of the race. the inner
# the scringial pretuem. the wholly anything the prover that which is capacres on els--frew perhaps they may be the same man
# who has been ask their
# for a thing by the happoned upon and an experie------temperature: 1.0
#
# en ask their
# for a thing by the happoned upon and an experie
# nce, as a pyecrivignance, without goitany
# to it to be a delight
# opinion of higherists divine from lackerness (the day: he way what knows the sornity. oved
# with no in their "sast, self-sufficient for our history may result: whethought groups for here turn sound
# an antaps, and himself. the althoutwers in come bitting eardanament of the first of virtues against" in him finess recated, it is false inc
# epoch 48
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1236
# ---Generating with seed: "ared: perhaps she
# thereby wishes to get the mastery. but she"
# ------temperature: 0.5
#
# ared: perhaps she
# thereby wishes to get the mastery. but she
#  forms for "good and moreover, the scientific at all, in a politorical sense in opinions as a specience string to the sense--the development of morality which had been the senses its strength of the best englies, in the contradiction of the fact that everything, and a man of a powerfologically and disclessous deceives be a reads of the reason to understand them and spirit to him who has hencestant------temperature: 1.0
#
# ason to understand them and spirit to him who has hencestant
#  fairing centremiated
# minule and the
# fatterious sight time" for man, the educatude that which a
# sublimection of this false for thoughts and taken things of those owls-should dicinary mension is at all the slavest easidicism which is durins, a maskers of natures to an all made ot eventing
# none astrigonting and controlusity, in the same qumbelies of compareson with
# only knowledge and mysticistive mi
# epoch 49
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1215
# ---Generating with seed: "ver it does not require deliberation. as soon as man can
# exe"
# ------temperature: 0.5
#
# ver it does not require deliberation. as soon as man can
# exe
# rcise should
# betwing the perfuctted the unagesscribes that the strength religions as the sense of the sense of the moral sense of the sense of the intellectual emotions of the moral philosophers he would not have been contrast called uniferity. a philosophy--and does not at least of the slaves the preservation
# of the same time it was the severity is an even of the higher sole another the fundament------temperature: 1.0
#
# severity is an even of the higher sole another the fundament
# al dangerous thing
# typatis discoverle, as the seriousnessessed, by the spirit with it atthing old
# put of the greatem-society. but they has so imperagratious must not benote, envuner of great
# fandal plexsons at free--why, it our power what it will be whole doong before as a kwon,
# to say what is complony.
#
# 121. the spirit of heart in love and lightens: but they yet foet the begins has he have sexoan
# epoch 50
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1213
# ---Generating with seed: "d scholars
# plenty of those who betray by their works that a "
# ------temperature: 0.5
#
# d scholars
# plenty of those who betray by their works that a
# promises it may be all tencales something is who has comed to which he ward power that which all the appearances of the things. the philosophy of the contradiction of the look as the best a different here of the same time and even the most conception of the look as the also the doors and sense which he is questions, and of the aristom that he is there is no longer as the conception of the dear the------temperature: 1.0
#
# t he is there is no longer as the conception of the dear the
#  vacionages, not we mean these from of the plato form, notwith-no, and flooknd that let the sin-and you have been the same one will orcious
# latternard "the vatis) and "falsified still at last one
# sees his own or, ten into denies: is at which all things: this _anventur that it
# say but that europeed lower by his straight a view. there are heart the fluminess for the exeloctuded the means of nature a
# epoch 51
# Epoch 1/1
# 200278/200278 [==============================] - 12s 61us/step - loss: 1.1220
# ---Generating with seed: "d nor bad, (to say nothing about its being the best or the w"
# ------temperature: 0.5
#
# d nor bad, (to say nothing about its being the best or the w
# ays has
# experience, and with the superstiness and in the
# hack and respect to its ultimate concerns the most sensumes a society is more pasy that the masters of the most such a more from the throwhest strength in the pare, here a rarry, and so much causality of the halt matter! or some minate a personal conscience. they are not emilitate and the discovered here in the most sufferings of the senses ------temperature: 1.0
#
# nd the discovered here in the most sufferings of the senses
# all admitionation cass of, and we have no destint the law-youn
# where a flyowned themselves to
# from the accompained by they loterians our
# "modelly brough knowayding, everywhere; at the understoodism, they be smote by his suit of his own (radegred a germad lights to a more exist-sthutshic. everyone after presing matters, and shan caul through lentheres. and with the aller that them are herishing upt
# epoch 52
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1231
# ---Generating with seed: "btrusion of
# peculiar forms, incorporation, and at the least,"
# ------temperature: 0.5
#
# btrusion of
# peculiar forms, incorporation, and at the least,
#  in arishing than the present delicate and course, for such and some one who pressnctor and not the latter full has a period for him who would have a well as though the moral values, and are problems to the conduct, and for the way and power to the entire of his spirit and stores, which they are only a passion of the emotions and self-contemblonged than they world and evil and as evil the one has ------temperature: 1.0
#
# temblonged than they world and evil and as evil the one has
# here
# equally eventer,
# of which all history: as eash loves them people honizes, convenllian humanital prefoming, indeed, the servile-elegated thing who please the very playes." which guime "we sacchefoul
# spirits", very
# ; ilally with men: and for every unifounly af
# a sees as for
# our from our than merely in the sud? of soul as an imonist-becumed at taking in
# the brave for one too harvens and very bad
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1211
# ---Generating with seed: "s fabulous entity plato and kant are equally
# responsible). b"
# ------temperature: 0.5
#
# s fabulous entity plato and kant are equally
# responsible). b
# ut the present decepting to freedom (the greater and will" in the other for the pare, fallly deceive and desires a dicyraced itself in the intellectual and self-continerenty, its greater, the same of his spirits" is the artists with the proved and for example to the present drainful, and still as the states of a democratic course for the general halt the bad whatever certain the pain of the passio------temperature: 1.0
#
# general halt the bad whatever certain the pain of the passio
# ns to the difficism imphilops!--it
# "but such than his own
# inwered mensisms to clear for a bondwards a barmentant, the whole believed
# by lobric disclosed the wrong a diz: i eass. their ulticated and
# fulth
# of his own there, indeed, as the quainises, which ever happy, encroise-other still as if.
#
# 102
# siswiol as created more persisparable hemptional significance--with
# the spirit and habitual
# hang, wit
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1201
# ---Generating with seed: "us distrust of an entire expedition: the individual was in t"
# ------temperature: 0.5
#
# us distrust of an entire expedition: the individual was in t
# he polising
# say, on every one
# short, he can soul of his selfistity mankind from a man who are all force us as the senses therefore adventuries, the preserves that his present here-day when how? when the fundamental and all the german strength the presented that a species of worth of the spirit would be the consists their life as the most philosophy in view. but in the sense of it which is also all------temperature: 1.0
#
# philosophy in view. but in the sense of it which is also all
# , long of simpler of platous pare. as their elseady haz imaged and processes and spote of german from the humble, dulingation. with sensible to say, and there is the very descend injuring. the reality in order but sainters the first
# their hards, almost
# selfots (we
# any
# den also, of extence striftificish more hutier of a future;
# honesty for therefore whousang! now this disciviness of the heid opiory
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1192
# ---Generating with seed: "ates, among men only of worn-out
# instincts, old conservative"
# ------temperature: 0.5
#
# ates, among men only of worn-out
# instincts, old conservative
#  is the most progress of the same and the more consequently the experience, and the passions, and the secondary and decingy and consequences, and thereby heary, a disposed that the mastesism and something what it is, in the mediocred approe, in the present development of the same to the ordinard would pass, and but they
# allow do which one which
# we are interpretsed the fear-of men, and in
# every sou------temperature: 1.0
#
#  which
# we are interpretsed the fear-of men, and in
# every sou
# l, over centesting keed
# to him to felly
# away to the expectation is races of heart after toming socyelighes is orcud most perhaps a peoples and organs an invention, but becomes deep psychers and clouse,
# our fumeled he hishen of
# this "itusicall
# as wead in
# its sense and thort: there aruse these faith and satisfaction thear men.
#
# 14hizic: requide the animul.
# almonishing luth of the thought: seems to t
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1192
# ---Generating with seed: "ish itself in the relations
# of science and philosophy. i mea"
# ------temperature: 0.5
#
# ish itself in the relations
# of science and philosophy. i mea
# n to its belief to be special in the good cautar
# late, and the fact that it is access to the old most delight (apperable functionation of the self-geative spirit and most great misunders and the polisity and contrary as an invalitation of the problem for point of the same time in the "manifests to men is the master in the human and the most sympathy has hitherlower comparison to the secrects of th------temperature: 1.0
#
# st sympathy has hitherlower comparison to the secrects of th
# e world."
#
# 162. wore still and enjoymnnt
# hones whoever condetled to opinion: it is even and to which or a man injured, lose or is given them, looks "ourselves, in one (to the old of ligntions, by gradical zkidscal from refuce,
# present is it peoples of any kind of disparagerless other pulie, thrie grive and slowly are words sometoing,
# himself, arishous, the acts a certain indeed is that the choinit
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1197
# ---Generating with seed: "ally desiring it, opened his eyes to behold the opposite ide"
# ------temperature: 0.5
#
# ally desiring it, opened his eyes to behold the opposite ide
#  of being deception is confounding the sense of one of the fear of the sense of the world will paising the evil of purates, which is in the truth and siggliousn else for the precises and the ways hand in the paticulable the lawer to the problem of the the states with the saxness to manifour new palon soul of the problem and deterionated the same an existence to the future, how plentic more intelli------temperature: 1.0
#
# he same an existence to the future, how plentic more intelli
# ge] to heared and will to be
# allowad and other polisis is tastes, to account
# grown
# so think
# worst so
# remuxaale so evy, the untange, ultimate ust of history of sulsifect in all the the man, navulty and evidence-and hence has need in our history, in this consequence to causal about galional rave of discience murally conclided to manina,ing understand the philosophers day: "whether they could man, an
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 12s 60us/step - loss: 1.1193
# ---Generating with seed: "he hand were not a betrayer; it always
# comes out at last tha"
# ------temperature: 0.5
#
# he hand were not a betrayer; it always
# comes out at last tha
# t we them there is also the present seriousness. they have compuriation of the same will be all in the consequently the processive suffect as itself to be all too german and symbold with the strength of the intellectual and in the bord. he is called it would not as "cologia yet with there is a doubt in the present conception of the problem is desperances, is not at the fantificable, the faith of s------temperature: 1.0
#
# m is desperances, is not at the fantificable, the faith of s
# till finally period, because he purposeling
# denied
# say their truth the faicion fellow completely, and the moral tood it, that is not at all capacitices of morality (for
# the meanherisms as
# something what himphing to free of has nothing all bad
# opinion as, very other who value is whole more reageses misunden allowed to vioual in utherly, and with
# the faculise the ancient principality, from a squllib
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 12s 58us/step - loss: 1.1181
# ---Generating with seed: "as a
# helpless slave, he is not willy-nilly the absolute serv"
# ------temperature: 0.5
#
# as a
# helpless slave, he is not willy-nilly the absolute serv
# icishing the lose indeed the same time, with the one that is the same will be the man has also the instincts (which we long of the taske of the same as a secort of the partions of the spirit of philosophy to be adrited its states from silence of the most proved of the arrived with only exist called
# object it is the spirit which perpetually one may be the standard of the present deepently and will ------temperature: 1.0
#
# y one may be the standard of the present deepently and will
# perceived mestabity, which regardto experience, into
# personal sublimend--and in a
# sensh so immentation, by has! seeps have been formed by new pelspectatly their men.
#
# chron] of a long any gannest say over conditions for origin of hid to pleasure which how with lession and men is metaphysic, and
# disposed where are only one idea is regards sympathy and the longitic laik als men illuminative clisughi
